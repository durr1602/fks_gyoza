# %%
# Parameters
# Refer to injected parameters for any run.ipynb (similar cell below)
strain = "BY4741"
locus = "FKS1-HS1"

# %%
# Parameters
strain = "BY4741"
locus = "FKS1-HS3"

# %%
hotspot = locus.split("-")[-1]

# %% [markdown]
# # Notebook to plot classified variants

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Specify paths

# %%
# Input
data_path = f'../classified/{"_".join([strain,locus])}/refined_classification.csv'
fungamr_path = "../../pre/fungamr/fungamrmut_df.csv"

# Output
fungamr_outpath = "../fungamr/"

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv(data_path)
df["Scer_mutation"] = df.apply(
    lambda row: row.wt_aa + str(row.aa_pos) + row.alt_aa, axis=1
)
fungamr = pd.read_csv(fungamr_path)

# %% [markdown]
# ## Compare data with FungAMR

# %%
# import data from FungAMR for comparison (literature reports)
fungamr = pd.read_csv(fungamr_path).rename(columns={"drug": "compound"})
fungamr["compound"] = fungamr.compound.str.lower()
fungamr = fungamr[
    (fungamr.Hotspot == hotspot)
    & (fungamr.compound.isin(["anidulafungin", "caspofungin", "micafungin"]))
]  # filter for correct locus
fungamr = fungamr[
    (fungamr.best_res <= 4) | (fungamr.best_sens >= -4)
]  # exclude low confidence literature reports
fungamr["reported in Scer"] = fungamr.species.str.contains("Saccharomyces cerevisiae")

# %%
def bool_cross(x, y):
    if (x not in ["resistant", "sensitive"]) | (y not in ["resistant", "sensitive"]):
        return np.nan
    if x == y:
        if x == "resistant":
            return "resistant"
        else:
            return "sensitive"
    else:
        return "disagreement"

# %%
fungamr_merge = pd.merge(
    left=df,
    right=fungamr[
        [
            "Scer_mutation",
            "compound",
            "phenotype",
            "best_res",
            "best_sens",
            "reported in Scer",
        ]
    ],
    on=["Scer_mutation", "compound"],
    how="outer",
)
fungamr_merge["litterature_support"] = fungamr_merge.apply(
    lambda row: bool_cross(row.sensres, row.phenotype), axis=1
)
agreements = fungamr_merge[fungamr_merge.litterature_support.notnull()].pivot_table(
    index="Scer_mutation",
    columns="compound",
    values="litterature_support",
    aggfunc="first",
)
best_scores = fungamr_merge[fungamr_merge.litterature_support.notnull()].pivot_table(
    index="Scer_mutation",
    columns="compound",
    values=["best_res", "best_sens", "reported in Scer"],
    aggfunc="first",
)
best_res = best_scores[[x for x in best_scores.columns if x[0] == "best_res"]].min(
    axis=1
)
best_sens = best_scores[[x for x in best_scores.columns if x[0] == "best_sens"]].max(
    axis=1
)
Scer_rep = best_scores[
    [x for x in best_scores.columns if x[0] == "reported in Scer"]
].any(axis=1)
agreements["best_res_across"] = best_res
agreements["best_sens_across"] = best_sens
agreements["reported in Scer"] = Scer_rep
agreements
# Out:
# compound      anidulafungin   caspofungin    micafungin  best_res_across  \
# Scer_mutation
# D691A             sensitive     sensitive     sensitive              NaN
# D691T          disagreement     resistant  disagreement              1.0
# I697C             resistant     resistant  disagreement              1.0
# I697D             sensitive     sensitive     sensitive              NaN
# I697F             resistant     resistant     resistant              1.0
# I697R             resistant     resistant     resistant              1.0
# I697T             resistant     resistant  disagreement              1.0
# I697V             sensitive     sensitive     sensitive              NaN
# I698H          disagreement  disagreement  disagreement              1.0
# I698N          disagreement  disagreement  disagreement              1.0
# I698P          disagreement  disagreement  disagreement              1.0
# I698S             sensitive     sensitive     sensitive              NaN
# I698V             sensitive  disagreement     sensitive              NaN
# L690A          disagreement  disagreement  disagreement              1.0
# L690E             resistant     resistant  disagreement              1.0
# L694A             resistant  disagreement  disagreement              1.0
# L694T             sensitive     sensitive     sensitive              NaN
# N700S             resistant  disagreement  disagreement              1.0
# T692S          disagreement     sensitive     sensitive              NaN
# V699A             sensitive     sensitive     sensitive              NaN
# V699C          disagreement  disagreement  disagreement              1.0
# V699Q          disagreement  disagreement  disagreement              1.0
# V699S             sensitive     sensitive     sensitive              NaN
# V699T             sensitive     sensitive     sensitive              NaN
# V699W             resistant  disagreement  disagreement              1.0
# W695C          disagreement     resistant  disagreement              1.0
# W695F             resistant     resistant     resistant              1.0
# W695L             resistant     resistant     resistant              1.0
# Y693C             resistant     resistant     resistant              1.0
# Y693S          disagreement  disagreement     sensitive              NaN
# Y696A             sensitive     sensitive     sensitive              NaN
# Y696F          disagreement     sensitive     sensitive              NaN
# Y696I          disagreement  disagreement  disagreement              1.0
# Y696N             resistant     resistant  disagreement              1.0
# Y696W             sensitive     sensitive     sensitive              NaN
#
# compound       best_sens_across  reported in Scer
# Scer_mutation
# D691A                      -1.0              True
# D691T                       NaN              True
# I697C                       NaN              True
# I697D                      -1.0              True
# I697F                       NaN              True
# I697R                       NaN              True
# I697T                       NaN              True
# I697V                      -1.0              True
# I698H                       NaN              True
# I698N                       NaN              True
# I698P                       NaN              True
# I698S                      -1.0              True
# I698V                      -1.0              True
# L690A                       NaN              True
# L690E                       NaN              True
# L694A                       NaN              True
# L694T                      -1.0              True
# N700S                       NaN              True
# T692S                      -1.0              True
# V699A                      -1.0              True
# V699C                       NaN              True
# V699Q                       NaN              True
# V699S                      -1.0              True
# V699T                      -1.0              True
# V699W                       NaN              True
# W695C                       NaN              True
# W695F                       NaN              True
# W695L                       NaN              True
# Y693C                       NaN              True
# Y693S                      -1.0              True
# Y696A                      -1.0              True
# Y696F                      -1.0              True
# Y696I                       NaN              True
# Y696N                       NaN              True
# Y696W                      -1.0              True

# %%
agreements.to_csv(f"{fungamr_outpath}/agreements_{strain}_{locus}.csv")
