# %%
# Parameters
# Refer to injected parameters for any run.ipynb (similar cell below)
strain = "BY4741"
locus = "FKS1-HS3"
aggdata_outpath = "../../results/df/avg_scores_HS3.csv"

# %%
# Parameters
strain = "R1158"
locus = "FKS2-HS1"
aggdata_outpath = "../../results/df/avg_scores.csv"

# %% [markdown]
# # Notebook to train a Gaussian mixture model

# %% [markdown]
# The model is trained on DMS data and used to predict the different classes of mutational effects

# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
from sklearn.mixture import GaussianMixture
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams["svg.fonttype"] = "none"

# %% [markdown]
# ## Specify paths

# %%
### Output
classified_outpath = f'../classified/{"_".join([strain,locus])}/'
if not os.path.exists(classified_outpath):
    os.makedirs(classified_outpath)

graph_outpath = "../graphs/"

# %% [markdown]
# ## Import data

# %%
master = pd.read_csv(aggdata_outpath).rename(
    columns={
        "Mutated_seq": "locus",
        "fitness_T2": "s",
        "lower_err_T2": "min_s",
        "upper_err_T2": "max_s",
    }
)
master
# Out:
#       strain paralog hotspot     locus       compound  Nham_aa     aa_seq  \
# 0     BY4741    FKS1     HS1  FKS1-HS1  anidulafungin        0  FLVLSLRDP
# 1     BY4741    FKS1     HS1  FKS1-HS1  anidulafungin        1  *LVLSLRDP
# 2     BY4741    FKS1     HS1  FKS1-HS1  anidulafungin        1  ALVLSLRDP
# 3     BY4741    FKS1     HS1  FKS1-HS1  anidulafungin        1  DLVLSLRDP
# 4     BY4741    FKS1     HS1  FKS1-HS1  anidulafungin        1  ELVLSLRDP
# ...      ...     ...     ...       ...            ...      ...        ...
# 2331   R1158    FKS2     HS2  FKS2-HS2           none        1   SWVRRYTL
# 2332   R1158    FKS2     HS2  FKS2-HS2           none        1   TWVRRYTL
# 2333   R1158    FKS2     HS2  FKS2-HS2           none        1   VWVRRYTL
# 2334   R1158    FKS2     HS2  FKS2-HS2           none        1   WWVRRYTL
# 2335   R1158    FKS2     HS2  FKS2-HS2           none        1   YWVRRYTL
#
#               aa_pos          alt_aa           wt_aa         s     min_s  \
# 0     not-applicable  not-applicable  not-applicable -0.043464  0.014874
# 1                639               *               F  0.272017  0.270748
# 2                639               A               F  1.149748  0.059427
# 3                639               D               F -0.054513  0.144288
# 4                639               E               F  0.417593  0.070150
# ...              ...             ...             ...       ...       ...
# 2331            1372               S               D -0.000122  0.036527
# 2332            1372               T               D  0.014759  0.024885
# 2333            1372               V               D  0.008197  0.016583
# 2334            1372               W               D -0.029963  0.000474
# 2335            1372               Y               D -0.002703  0.008272
#
#          max_s
# 0     0.014874
# 1     0.270748
# 2     0.059427
# 3     0.144288
# 4     0.070150
# ...        ...
# 2331  0.052768
# 2332  0.009746
# 2333  0.003564
# 2334  0.010167
# 2335  0.019239
#
# [2336 rows x 13 columns]

# %% [markdown]
# ## GMM

# %%
GMMdf = (
    master[(master.strain == strain) & (master.locus == locus)]
    .groupby(["compound", "aa_seq", "Nham_aa", "aa_pos", "alt_aa", "wt_aa"])[
        ["s", "min_s", "max_s"]
    ]
    .agg(s=("s", "first"), min_s=("min_s", "first"), max_s=("max_s", "first"))
    .reset_index()
)
GMMdf
# Out:
#           compound    aa_seq  Nham_aa aa_pos alt_aa wt_aa         s     min_s  \
# 0    anidulafungin  *ILSLRDP        1    659      *     L  0.272922  0.014782
# 1    anidulafungin  AILSLRDP        1    659      A     L  0.563838  0.071382
# 2    anidulafungin  DILSLRDP        1    659      D     L  0.107963  0.071144
# 3    anidulafungin  EILSLRDP        1    659      E     L  0.249177  0.141921
# 4    anidulafungin  FILSLRDP        1    659      F     L -0.171773  0.039435
# ..             ...       ...      ...    ...    ...   ...       ...       ...
# 625           none  SILSLRDP        1    659      S     L -0.069446  0.009805
# 626           none  TILSLRDP        1    659      T     L -0.007672  0.008295
# 627           none  VILSLRDP        1    659      V     L -0.005994  0.001754
# 628           none  WILSLRDP        1    659      W     L -0.014110  0.020532
# 629           none  YILSLRDP        1    659      Y     L -0.021273  0.012946
#
#         max_s
# 0    0.077393
# 1    0.032137
# 2    0.038323
# 3    0.003556
# 4    0.137061
# ..        ...
# 625  0.036988
# 626  0.007027
# 627  0.007694
# 628  0.007342
# 629  0.027366
#
# [630 rows x 9 columns]

# %% [markdown]
# ### Optimize model

# %%
# Set specific seed
seed = 25  # Set value for repetability

# Initialize dictionary to store parameters for each condition
model_dict = {}

# Specify order of conditions
lcomp = ["none", "dox", "anidulafungin", "caspofungin", "micafungin"]

# Optimize model for every condition (here, compound) separately
for j, c in enumerate(lcomp):
    if c in GMMdf.compound.unique():
        # The goal is to minimize AIC and BIC, but mostly BIC
        X = GMMdf[GMMdf.compound == c].s.values.reshape(-1, 1)
        N = np.arange(1, 6)
        models = [None for i in range(len(N))]  # testing up to 1-5 components
        # 5 is the max number of biologically relevant classes: deleterious, WT-like, intermediary, resistant, very resistant
        for i in range(len(N)):
            models[i] = GaussianMixture(n_components=N[i], random_state=seed).fit(
                X, y=None
            )

        # Compute AIC and BIC
        AIC = [m.aic(X) for m in models]
        BIC = [m.bic(X) for m in models]

        # Save parameters to dictionary
        model_dict[c.title()] = (N, AIC, BIC)

# %%
model_df = pd.DataFrame.from_dict(
    model_dict, orient="index", columns=["components", "AIC", "BIC"]
).reset_index(names="compound")
model_df = model_df.explode(["components", "AIC", "BIC"]).melt(
    ["compound", "components"], var_name="IC"
)

# %%
# Purge graph space
sns.set_theme(
    rc={
        "font.family": "Arial",
        "font.size": 8,
        "legend.title_fontsize": 8,
        "legend.fontsize": 8,
        "axes.labelsize": 8,
        "axes.titlesize": 8,
        "xtick.labelsize": 8,
        "ytick.labelsize": 8,
        "xtick.major.pad": 2,
        "ytick.major.pad": 2,
        "xtick.bottom": True,
        "ytick.left": True,
        "xtick.major.size": 2,
        "ytick.major.size": 2,
    },
    style="ticks",
)

fig = sns.relplot(
    data=model_df,
    col="compound",
    x="components",
    y="value",
    hue="IC",
    style="IC",
    kind="line",
    height=2,
    facet_kws={"sharey": False, "despine": False},
)

fig.set_titles(row_template="{row_name}", col_template="{col_name}")
fig.set_axis_labels("Components", "Information criterion")
sns.move_legend(fig, "upper left", bbox_to_anchor=(0.175, 0.88), title=None)
plt.savefig(
    f'{graph_outpath}/{"_".join([strain,locus])}_GMM_BIC.svg', format="svg", dpi=300
)

# %%
for c, y in model_dict.items():  # for each compound
    print(
        c, np.argmin(y[1]) + 1
    )  # display the optimal number of components for the GMM
# Out:
# None 3
# Dox 5
# Anidulafungin 5
# Caspofungin 3
# Micafungin 3

# %% [markdown]
# ### Run model

# %%
# Define the number of components (number of mods)
mods = 3

# Define range
mini = round(GMMdf.s.min()) - 1
maxi = round(GMMdf.s.max()) + 1

# Initialize list of df
proba_list = []

for i, c in enumerate(model_dict.keys()):  # For every compound
    X = GMMdf[GMMdf.compound == c.lower()].s.values.reshape(-1, 1)
    M_best = GaussianMixture(n_components=mods, random_state=seed).fit(X, y=None)
    GMMdf.loc[GMMdf.compound == c.lower(), "label"] = M_best.predict(X)

    x = np.linspace(mini, maxi, len(GMMdf[GMMdf.compound == c.lower()]))
    logprob = M_best.score_samples(x.reshape(-1, 1))
    responsibilities = M_best.predict_proba(x.reshape(-1, 1))
    pdf = np.exp(logprob)
    pdf_individual = responsibilities * pdf[:, np.newaxis]

    # Convert to dataframe
    indiv_df = pd.DataFrame(pdf_individual)
    indiv_df["x"] = x
    indiv_df = indiv_df.melt(id_vars="x", var_name="label", value_name="p(x)")
    indiv_df["compound"] = c
    proba_list.append(indiv_df)

proba_df = pd.concat(proba_list, ignore_index=True)
hist_df = GMMdf.copy()
hist_df["compound"] = hist_df.compound.apply(lambda x: x.title())

# %%
if os.path.exists(f"{classified_outpath}/thresholds.csv"):
    stddf = pd.read_csv(f"{classified_outpath}/thresholds.csv")
else:
    stddf = pd.DataFrame()
    print("Need to calculate thresholds. Will not display in next plot.")

# %%
# Purge graph space
sns.set_theme(
    rc={
        "font.family": "Arial",
        "font.size": 8,
        "legend.title_fontsize": 8,
        "legend.fontsize": 8,
        "axes.labelsize": 8,
        "axes.titlesize": 8,
        "xtick.labelsize": 8,
        "ytick.labelsize": 8,
        "xtick.major.pad": 2,
        "ytick.major.pad": 2,
        "xtick.bottom": True,
        "ytick.left": True,
        "xtick.major.size": 2,
        "ytick.major.size": 2,
    },
    style="ticks",
)

fig = sns.relplot(
    proba_df,
    col="compound",
    x="x",
    y="p(x)",
    hue="label",
    kind="line",
    height=2,
    legend=False,
    facet_kws={"sharey": False, "despine": False},
)

fig.set_titles(row_template="{row_name}", col_template="{col_name}")

for i, c in enumerate(proba_df.compound.unique()):
    fig.axes[0][i].hist(
        hist_df[hist_df.compound == c].s,
        30,
        density=True,
        histtype="stepfilled",
        color=".8",
    )
    if not stddf.empty:
        fig.axes[0][i].axvline(
            x=stddf[stddf.compound == c.lower()].val.tolist()[0], ls="--", color="grey"
        )
        fig.axes[0][i].axvline(
            x=stddf[stddf.compound == c.lower()].val.tolist()[1], ls="--", color="grey"
        )

plt.savefig(
    f'{graph_outpath}/{"_".join([strain,locus])}_GMM_densities.svg',
    format="svg",
    dpi=300,
)

# %%
# Looking at the predicted labels for each condition and the mean value to properly convert the label into a class
label_mean = (
    GMMdf.groupby(["compound", "label"])[["s"]]
    .agg(["size", "mean"])
    .reset_index()
    .sort_values(by=[("compound", ""), ("s", "mean")])
)
label_mean
# Out:
#          compound label    s
#                         size      mean
# 0   anidulafungin   0.0   99  0.006710
# 2   anidulafungin   2.0   12  0.658290
# 1   anidulafungin   1.0   15  1.474947
# 3     caspofungin   0.0   86 -0.013078
# 5     caspofungin   2.0   21  0.467295
# 4     caspofungin   1.0   19  1.328533
# 7             dox   1.0   10 -0.800870
# 8             dox   2.0   32 -0.097120
# 6             dox   0.0   84 -0.010094
# 9      micafungin   0.0   51 -0.051816
# 11     micafungin   2.0   39  0.466591
# 10     micafungin   1.0   36  1.178727
# 13           none   1.0   11 -0.063584
# 14           none   2.0   99 -0.003185
# 12           none   0.0   16 -0.002728

# %% [markdown]
# ### Convert classification labels

# %%
class_dict = {}
class_list = ["WT-like", "intermediary", "resistant"]
none_list = {
    "FKS1-HS1": ["deleterious", "slightly deleterious", "WT-like"],
    "FKS1-HS2": ["WT-like", "WT-like", "WT-like"],
    "FKS1-HS3": ["deleterious", "slightly deleterious", "WT-like"],
    "FKS2-HS1": ["slightly deleterious", "WT-like", "WT-like"],
    "FKS2-HS2": ["slightly deleterious", "WT-like", "WT-like"],
}
dox_list = {
    "FKS1-HS1": ["deleterious", "slightly deleterious", "WT-like"],
    "FKS2-HS1": ["deleterious", "slightly deleterious", "WT-like"],
    "FKS2-HS2": ["deleterious", "slightly deleterious", "WT-like"],
}

for c in label_mean.compound.unique():
    class_dict[c] = {}

i = 0
for c, l in zip(label_mean.compound, label_mean.label):
    i = len(class_dict[c])
    if c in ["anidulafungin", "caspofungin", "micafungin"]:
        class_dict[c][l] = class_list[i]
    elif c == "none":
        if locus in none_list.keys():
            class_dict[c][l] = none_list[locus][i]
        else:
            class_dict[c][l] = "error"
    elif c == "dox":
        if locus in dox_list.keys():
            class_dict[c][l] = dox_list[locus][i]
        else:
            class_dict[c][l] = "error"
    else:
        class_dict[c][l] = "error"

class_dict
# Out:
# {'anidulafungin': {0.0: 'WT-like', 2.0: 'intermediary', 1.0: 'resistant'},
#  'caspofungin': {0.0: 'WT-like', 2.0: 'intermediary', 1.0: 'resistant'},
#  'dox': {1.0: 'deleterious', 2.0: 'slightly deleterious', 0.0: 'WT-like'},
#  'micafungin': {0.0: 'WT-like', 2.0: 'intermediary', 1.0: 'resistant'},
#  'none': {1.0: 'slightly deleterious', 2.0: 'WT-like', 0.0: 'WT-like'}}

# %%
GMMdf["rclass"] = GMMdf.apply(lambda row: class_dict[row.compound][row.label], axis=1)
GMMdf
# Out:
#           compound    aa_seq  Nham_aa aa_pos alt_aa wt_aa         s     min_s  \
# 0    anidulafungin  *ILSLRDP        1    659      *     L  0.272922  0.014782
# 1    anidulafungin  AILSLRDP        1    659      A     L  0.563838  0.071382
# 2    anidulafungin  DILSLRDP        1    659      D     L  0.107963  0.071144
# 3    anidulafungin  EILSLRDP        1    659      E     L  0.249177  0.141921
# 4    anidulafungin  FILSLRDP        1    659      F     L -0.171773  0.039435
# ..             ...       ...      ...    ...    ...   ...       ...       ...
# 625           none  SILSLRDP        1    659      S     L -0.069446  0.009805
# 626           none  TILSLRDP        1    659      T     L -0.007672  0.008295
# 627           none  VILSLRDP        1    659      V     L -0.005994  0.001754
# 628           none  WILSLRDP        1    659      W     L -0.014110  0.020532
# 629           none  YILSLRDP        1    659      Y     L -0.021273  0.012946
#
#         max_s  label                rclass
# 0    0.077393    0.0               WT-like
# 1    0.032137    2.0          intermediary
# 2    0.038323    0.0               WT-like
# 3    0.003556    0.0               WT-like
# 4    0.137061    0.0               WT-like
# ..        ...    ...                   ...
# 625  0.036988    1.0  slightly deleterious
# 626  0.007027    2.0               WT-like
# 627  0.007694    2.0               WT-like
# 628  0.007342    2.0               WT-like
# 629  0.027366    2.0               WT-like
#
# [630 rows x 11 columns]

# %%
GMMdf.to_csv(f"{classified_outpath}/raw_classification.csv")

# %% [markdown]
# ## Breakdown: number of variants per class

# %%
GMMdf = pd.read_csv(f"{classified_outpath}/raw_classification.csv", index_col=0)

# %%
GMMdf.groupby(["compound", "rclass"])[["s"]].agg(["size", "median"])
# Out:
#                                       s
#                                    size    median
# compound      rclass
# anidulafungin WT-like                99 -0.019614
#               intermediary           12  0.654178
#               resistant              15  1.437250
# caspofungin   WT-like                86 -0.019590
#               intermediary           21  0.442457
#               resistant              19  1.311468
# dox           WT-like                84 -0.009244
#               deleterious            10 -0.783362
#               slightly deleterious   32 -0.095051
# micafungin    WT-like                51 -0.054301
#               intermediary           39  0.493120
#               resistant              36  1.165515
# none          WT-like               115 -0.003539
#               slightly deleterious   11 -0.054212

# %% [markdown]
# ## Refine classification (resolve overlaps)

# %% [markdown]
# To resolve overlaps , I use the distributions to define thresholds. However, because only the "resistant" and "WT-like" distributions (as called by the GMM) are narrow, we define the thresholds only for these groups. "Intermediary", "deleterious", etc end up being the label of variants which **did not** cross the thresholds.

# %% [markdown]
# ### Step 1 - Set thresholds from narrow distributions

# %%
zthresh = 2.5  # set threshold in z-score

# %%
distri_params = (
    GMMdf.groupby(["compound", "rclass"])[["s"]].agg(["mean", "std"]).reset_index()
)
distri_params.columns = [x[0] if x[1] == "" else x[1] for x in distri_params.columns]
distri_params["lower_bound"] = distri_params["mean"] - zthresh * distri_params["std"]
distri_params["upper_bound"] = distri_params["mean"] + zthresh * distri_params["std"]
distri_params
# Out:
#          compound                rclass      mean       std  lower_bound  \
# 0   anidulafungin               WT-like  0.006710  0.125249    -0.306412
# 1   anidulafungin          intermediary  0.658290  0.171232     0.230209
# 2   anidulafungin             resistant  1.474947  0.249733     0.850614
# 3     caspofungin               WT-like -0.013078  0.092543    -0.244436
# 4     caspofungin          intermediary  0.467295  0.184345     0.006433
# 5     caspofungin             resistant  1.328533  0.164733     0.916700
# 6             dox               WT-like -0.010094  0.018641    -0.056696
# 7             dox           deleterious -0.800870  0.087753    -1.020253
# 8             dox  slightly deleterious -0.097120  0.101919    -0.351919
# 9      micafungin               WT-like -0.051816  0.067441    -0.220419
# 10     micafungin          intermediary  0.466591  0.256873    -0.175593
# 11     micafungin             resistant  1.178727  0.158365     0.782814
# 12           none               WT-like -0.003121  0.017269    -0.046293
# 13           none  slightly deleterious -0.063584  0.018078    -0.108779
#
#     upper_bound
# 0      0.319833
# 1      1.086371
# 2      2.099281
# 3      0.218281
# 4      0.928157
# 5      1.740366
# 6      0.036509
# 7     -0.581487
# 8      0.157678
# 9      0.116787
# 10     1.108774
# 11     1.574640
# 12     0.040051
# 13    -0.018390

# %%
stdlist = []

for c in distri_params.compound.unique():
    if c in ["caspofungin", "micafungin", "anidulafungin"]:
        stdlist.append(
            [
                c,
                "low",
                distri_params.loc[
                    (distri_params.compound == c) & (distri_params.rclass == "WT-like"),
                    "upper_bound",
                ].values[0],
            ]
        )
        if locus in ["FKS1-HS1", "FKS1-HS3", "FKS2-HS1"]:
            stdlist.append(
                [
                    c,
                    "up",
                    distri_params.loc[
                        (distri_params.compound == c)
                        & (distri_params.rclass == "resistant"),
                        "lower_bound",
                    ].values[0],
                ]
            )
        elif locus in ["FKS1-HS2", "FKS2-HS2"]:
            stdlist.append(
                [
                    c,
                    "up",
                    distri_params.loc[
                        (distri_params.compound == c)
                        & (distri_params.rclass == "intermediary"),
                        "upper_bound",
                    ].values[0],
                ]
            )
        else:
            print("Please define locus-specific bound")
    else:
        stdlist.append(
            [
                c,
                "low",
                distri_params.loc[
                    (distri_params.compound == c) & (distri_params.rclass == "WT-like"),
                    "lower_bound",
                ].values[0],
            ]
        )
        stdlist.append([c, "up", None])

stddf = pd.DataFrame(stdlist, columns=["compound", "thresh", "val"])
stddf.to_csv(f"{classified_outpath}/thresholds.csv")
stddf
# Out:
#         compound thresh       val
# 0  anidulafungin    low  0.319833
# 1  anidulafungin     up  0.850614
# 2    caspofungin    low  0.218281
# 3    caspofungin     up  0.916700
# 4            dox    low -0.056696
# 5            dox     up       NaN
# 6     micafungin    low  0.116787
# 7     micafungin     up  0.782814
# 8           none    low -0.046293
# 9           none     up       NaN

# %%
fig = sns.catplot(
    GMMdf,
    x="compound",
    y="s",
    hue="rclass",
    hue_order=[
        "resistant",
        "intermediary",
        "WT-like",
        "slightly deleterious",
        "deleterious",
    ],
    palette="icefire_r",
    # alpha=.3
)

sns.boxplot(
    stddf,
    x="compound",
    y="val",
    hue="thresh",
    hue_order=["low", "up"],
    palette=["black", "orange"],
    fill=False,
    legend=False,
)
# Out:
# <Axes: xlabel='compound', ylabel='s'>

# %% [markdown]
# ### Step 2 - Refine classification

# %%
def refine_class(v, comp, threshdf):
    wtbound = threshdf.loc[
        (threshdf.compound == comp) & (threshdf.thresh == "low"), "val"
    ].values[0]
    resbound = threshdf.loc[
        (threshdf.compound == comp) & (threshdf.thresh == "up"), "val"
    ].values[0]

    if (comp in ["none", "dox"]) & (v > -0.7):
        if v >= wtbound:
            return "WT-like"
        else:
            return "slightly deleterious"
    elif (comp in ["none", "dox"]) & (v < -0.7):
        return "deleterious"
    else:
        if v <= wtbound:
            return "WT-like"
        elif v >= resbound:
            return "resistant"
        else:
            return "intermediary"

# %%
GMMdf["refined_class"] = GMMdf.apply(
    lambda row: refine_class(row.s, row.compound, stddf), axis=1
)
GMMdf
# Out:
#           compound    aa_seq  Nham_aa aa_pos alt_aa wt_aa         s     min_s  \
# 0    anidulafungin  *ILSLRDP        1    659      *     L  0.272922  0.014782
# 1    anidulafungin  AILSLRDP        1    659      A     L  0.563838  0.071382
# 2    anidulafungin  DILSLRDP        1    659      D     L  0.107963  0.071144
# 3    anidulafungin  EILSLRDP        1    659      E     L  0.249177  0.141921
# 4    anidulafungin  FILSLRDP        1    659      F     L -0.171773  0.039435
# ..             ...       ...      ...    ...    ...   ...       ...       ...
# 625           none  SILSLRDP        1    659      S     L -0.069446  0.009805
# 626           none  TILSLRDP        1    659      T     L -0.007672  0.008295
# 627           none  VILSLRDP        1    659      V     L -0.005994  0.001754
# 628           none  WILSLRDP        1    659      W     L -0.014110  0.020532
# 629           none  YILSLRDP        1    659      Y     L -0.021273  0.012946
#
#         max_s  label                rclass         refined_class
# 0    0.077393    0.0               WT-like               WT-like
# 1    0.032137    2.0          intermediary          intermediary
# 2    0.038323    0.0               WT-like               WT-like
# 3    0.003556    0.0               WT-like               WT-like
# 4    0.137061    0.0               WT-like               WT-like
# ..        ...    ...                   ...                   ...
# 625  0.036988    1.0  slightly deleterious  slightly deleterious
# 626  0.007027    2.0               WT-like               WT-like
# 627  0.007694    2.0               WT-like               WT-like
# 628  0.007342    2.0               WT-like               WT-like
# 629  0.027366    2.0               WT-like               WT-like
#
# [630 rows x 12 columns]

# %%
fig = sns.catplot(
    GMMdf,
    x="compound",
    y="s",
    hue="refined_class",
    hue_order=[
        "resistant",
        "intermediary",
        "WT-like",
        "slightly deleterious",
        "deleterious",
    ],
    palette="icefire_r",
    # alpha=.3
)

sns.boxplot(
    stddf,
    x="compound",
    y="val",
    hue="thresh",
    hue_order=["low", "up"],
    palette=["black", "orange"],
    fill=False,
    legend=False,
)
# Out:
# <Axes: xlabel='compound', ylabel='s'>

# %% [markdown]
# ### Step 3 - Collapse classification (sensitive/resistant)

# %%
GMMdf["sensres"] = GMMdf.refined_class.replace(
    {
        "intermediary": "resistant",
        "WT-like": "sensitive",
        "slightly deleterious": "sensitive",
        "deleterious": "deleterious",
    }
)
GMMdf
# Out:
#           compound    aa_seq  Nham_aa aa_pos alt_aa wt_aa         s     min_s  \
# 0    anidulafungin  *ILSLRDP        1    659      *     L  0.272922  0.014782
# 1    anidulafungin  AILSLRDP        1    659      A     L  0.563838  0.071382
# 2    anidulafungin  DILSLRDP        1    659      D     L  0.107963  0.071144
# 3    anidulafungin  EILSLRDP        1    659      E     L  0.249177  0.141921
# 4    anidulafungin  FILSLRDP        1    659      F     L -0.171773  0.039435
# ..             ...       ...      ...    ...    ...   ...       ...       ...
# 625           none  SILSLRDP        1    659      S     L -0.069446  0.009805
# 626           none  TILSLRDP        1    659      T     L -0.007672  0.008295
# 627           none  VILSLRDP        1    659      V     L -0.005994  0.001754
# 628           none  WILSLRDP        1    659      W     L -0.014110  0.020532
# 629           none  YILSLRDP        1    659      Y     L -0.021273  0.012946
#
#         max_s  label                rclass         refined_class    sensres
# 0    0.077393    0.0               WT-like               WT-like  sensitive
# 1    0.032137    2.0          intermediary          intermediary  resistant
# 2    0.038323    0.0               WT-like               WT-like  sensitive
# 3    0.003556    0.0               WT-like               WT-like  sensitive
# 4    0.137061    0.0               WT-like               WT-like  sensitive
# ..        ...    ...                   ...                   ...        ...
# 625  0.036988    1.0  slightly deleterious  slightly deleterious  sensitive
# 626  0.007027    2.0               WT-like               WT-like  sensitive
# 627  0.007694    2.0               WT-like               WT-like  sensitive
# 628  0.007342    2.0               WT-like               WT-like  sensitive
# 629  0.027366    2.0               WT-like               WT-like  sensitive
#
# [630 rows x 13 columns]

# %%
GMMdf.to_csv(f"{classified_outpath}/refined_classification.csv", index=False)
